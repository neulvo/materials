# %% [markdown]
# # 해시
# https://school.programmers.co.kr/learn/courses/30/parts/12077
# ### 개념:
# >Hash function 해시 함수 (짧게는 그냥 해시)는 임의의 길이를 갖는 임의의 데이터를 고정된 길이의 데이터로 매핑하는 단방향 함수를 말한다.
#
# ### 유형:
# ####a. dictionary를 만든 후 조건에 맞는 값을 찾아주는 유형
# >폰켓몬 / 완주하지 못한 선수 / 전화번호 목록
#
# ####b. dictionary를 만든 후 새로운 조합을 만들어주는 유형
# >위장 / 베스트 앨범
#
# ### 킥: 일단 dictionary를 만들고 보자
# 1. 제한 사항을 잘 읽고 조건을 순서에 맞춰 잘 처리해주는 것이 중요
# 2. 딕셔너리의 get 함수 활용
# >get(self, key, default=None, /)
# >>Return the value for key if key is in the dictionary, else default.
#
#        d={}
#        for cloth, category in clothes:
#           d[category] = d.get(category,[]) + [cloth]
#
# ### 예제:
# https://school.programmers.co.kr/learn/courses/30/lessons/42579

# %% [markdown]
# #스택/큐
# https://school.programmers.co.kr/learn/courses/30/parts/12081
# ### 개념:
#
# >스택 : 후입선출(後入先出/Last In First Out—LIFO) 특성을 가지는 자료구조(Data Structure)를 일컫는다.
#
# ![image.png](data:image/png;base64,...)
#
# >큐 : 자료 구조의 한가지로, 먼저 집어 넣은 데이터가 먼저 나오는 FIFO(First In First Out)구조로 저장하는 형식을 말한다.
#
# ![image.png](data:image/png;base64,...)
#
# 자료 출처 : https://velog.io/@awesomeo184
#
# ### 유형:
# ####a. 스택: 짝 지어주기
# >올바른 괄호
#
# ####b. 큐: 밀어내기
# >같은 숫자는 싫어 / 기능개발 / 프린터 / 다리를 지나는 트럭
#
# ### 킥:
# ####a. 스택: 리스트의 마지막 항을 확인
#
# ####b. 큐: 리스트의 첫 항을 밀어내주기
#
# ####c.공통
# 1.빈 공간 만들어주기 / 빈 공간 추가해주기(시간 계산할 때)
#
# 2.any(iterable, /)
# > any(iterable, /)
# >>  Return True if bool(x) is True for any x in the iterable.
#     If the iterable is empty, return False.
#
#         if any(cur[1] < q[1] for q in queue):
#             queue.append(cur)
#
# ### 예제:
# https://school.programmers.co.kr/learn/courses/30/lessons/42583
#
# https://school.programmers.co.kr/learn/courses/30/lessons/42584

# %% [markdown]
# #힙
# https://school.programmers.co.kr/learn/courses/30/parts/12117
# ### 개념:
# >힙(heap)은 최댓값 및 최솟값을 찾아내는 연산을 빠르게 하기 위해 고안된 완전이진트리(complete binary tree)를 기본으로 한 자료구조(tree-based structure)로서 다음과 같은 힙 속성(property)을 만족한다.
#
# A가 B의 부모노드(parent node) 이면, A의 키(key)값과 B의 키값 사이에는 대소관계가 성립한다.
# 힙에는 두가지 종류가 있으며, 부모노드의 키값이 자식노드의 키값보다 항상 큰 힙을 '최대 힙', 부모노드의 키값이 자식노드의 키값보다 항상 작은 힙을 '최소 힙'이라고 부른다.
#
# 키값의 대소관계는 오로지 부모노드와 자식노드 간에만 성립하며, 특히 형제 사이에는 대소관계가 정해지지 않는다.
#
# ![image.png](data:image/png;base64,...)
#
# 자료 출처 : https://gmlwjd9405.github.io/2018/05/10/data-structure-heap.html
# ### 유형: 최소값 찾기
# >더 맵게 / 디스크 컨트롤러 / 이중우선순위큐
#
# ### 킥: import heapq
# >라이브러리 활용 및 힙의 구조 숙지하기
#
# ### 예제:
# https://school.programmers.co.kr/learn/courses/30/lessons/42627

# %% [markdown]
# #정렬
# https://school.programmers.co.kr/learn/courses/30/parts/12198
#
# ### 개념:
# >원소들을 번호순이나 사전 순서와 같이 일정한 순서대로 열거하는 알고리즘
#
# ### 유형: 정렬 후 원하는 아이템 찾기 / 만들기
# >K번째 수 / 가장 큰 수 / H-Index
#
# ### 킥: 한 번에 완벽하게 하지 않아도 된다
# 1. 제한 사항 활용하기
# 2. 정렬 함수의 key / lambda 함수 활용하기
# - sorted(iterable, /, *, key=None, reverse=False)
#   - Return a new list containing all items from the iterable in ascending order.
#
# - sort(self, /, *, key=None, reverse=False)
#
#       numbers.sort(key=lambda x: x*3, reverse=True)
# \* Multiple key 정렬이 가능하다
#       sorted_arr = sorted(dicList, key=lambda e: (-e['point'], e['penalty']))
#     >앞의 값이 같을 경우 뒤의 값을 활용해 정렬, 내림차순은 -를 붙여준다.
#
# 3. map 함수 / filter 함수 활용하기
# - class map(object)
#   - map(func, *iterables) --> map object
#     >Make an iterator that computes the function using arguments from
#     each of the iterables.  Stops when the shortest iterable is exhausted.
#
#         map(min, enumerate(citations, start=1))
#
# - class filter(object)
#   - filter(function or None, iterable) --> filter object
#     >Return an iterator yielding those items of iterable for which function(item) is true. If function is None, return the items that are true.
#
#         filter(lambda x: x>3,[1,2,3,4,5,6])
#
#
# ### 예제:
# https://school.programmers.co.kr/learn/courses/30/lessons/42747

# %% [markdown]
# #완전탐색
# https://school.programmers.co.kr/learn/courses/30/parts/12230
# ### 개념:
# >가능한 경우의 수를 모두 나열하면서 원하는 답을 찾는 방법
# ### 유형:
# ####a. 수학적 사고
# 최소 직사각형 / 모의고사 / 카펫 / 피로도
# ####b. 재귀/DFS/BFS
# 소수 찾기 / 전력망을 둘로 나누기 / 모음 사전
# ### 킥: 수학적 접근 방식이 낫지만 생각 안 나면 바로 itertools를 쓰자
# 1. 규칙 찾기
# 2. 조건 설정 후 집합의 크기 줄여나가기 / 작은 집합부터 만들어나가기
# 3. itertools 라이브러리 활용
# - https://docs.python.org/ko/3/library/itertools.html
# - https://puleugo.tistory.com/76
#
# ####예제
# https://school.programmers.co.kr/learn/courses/30/lessons/87946
#
# https://school.programmers.co.kr/learn/courses/30/lessons/86971

# %% [markdown]
# #탐욕법(Greedy)
# https://school.programmers.co.kr/learn/courses/30/parts/12244
# ### 개념:
# >탐욕 알고리즘은 최적해를 구하는 데에 사용되는 근사적인 방법으로, 여러 경우 중 하나를 결정해야 할 때마다 그 순간에 최적이라고 생각되는 것을 선택해 나가는 방식으로 진행하여 최종적인 해답에 도달한다.
#
# ### 유형: 두 개 (이상)의 선택지 혹은 집단의 비교
# >체육복 / 조이스틱 / 큰 수 만들기 / 구명보트 / 섬 연결하기 / 단속 카메라
#
# ### 킥: 집합을 나눠 생각하기
# 1. 중복을 허락하지 않을 경우 set()를 써라
# 2. 방향 혹은 크기 등의 비교를 할 때 한 쪽을 기준으로 잡아라
#
# ### 예제:
# https://school.programmers.co.kr/learn/courses/30/lessons/42860
#
# https://school.programmers.co.kr/learn/courses/30/lessons/42861

# %% [markdown]
# #동적계획법
# https://school.programmers.co.kr/learn/courses/30/parts/12263
# ### 개념:
# >복잡한 문제를 간단한 여러 개의 문제로 나누어 푸는 방법
# ### 유형: 둘 이상의 선택지
# >N으로 표현 / 정수 삼각형 / 등굣길
# ### 킥: 경우의 수를 나눠 생각하기 그리고 써놓기
# 1. 완전 탐색 활용하기
# 2. 조건 설정 후 filtering 해주기
# 3. 경우의 수에 따라 값을 update 시켜주기
#
# ### 예제:
# https://school.programmers.co.kr/learn/courses/30/lessons/43105
#
# https://school.programmers.co.kr/learn/courses/30/lessons/42898

# %% [markdown]
# #깊이/너비 우선 탐색(DFS/BFS)
# https://school.programmers.co.kr/learn/courses/30/parts/12421
# ### 개념:
# #### 깊이 우선 탐색(DFS):
# >트리나 그래프에서 한 루트로 탐색하다가 특정 상황에서 최대한 깊숙이 들어가서 확인한 뒤 다시 돌아가 다른 루트로 탐색하는 방식
# #### 너비 우선 탐색(BFS):
# >너비 우선 탐색은 맹목적 탐색방법의 하나로 시작 정점을 방문한 후 시작 정점에 인접한 모든 정점들을 우선 방문하는 방법이다. 더 이상 방문하지 않은 정점이 없을 때까지 방문하지 않은 모든 정점들에 대해서도 너비 우선 검색을 적용한다.
#
# ![image.png](data:image/png;base64,...)
# 자료 출처: https://velog.io/@chayezo/%EB%84%88%EB%B9%84-%EC%9A%B0%EC%84%A0-%ED%83%90%EC%83%89-BFS-Breadth-First-Search
# ### 유형: 조건을 만족하는 과정 찾기
# >타겟 넘버 / 네트워크 / 게임 맵 최단거리 / 단어 변환 / 아이템 줍기 / 여행 경로 / 퍼즐 조각 채우기
# ### 킥: 전체 과정을 탐색하며 답에 해당하는 과정을 리턴해줘라
# - 최단 / 최소 == 가장 먼저 만나는
#
# #### 추가:
# - DFS: 스택이나 재귀 함수로 구현
# - BFS: 큐로 구현
# - 참고 링크: https://cyc1am3n.github.io/2019/04/26/bfs_dfs_with_python.html
#
# ### 예제:
# https://school.programmers.co.kr/learn/courses/30/lessons/43162
#
# https://school.programmers.co.kr/learn/courses/30/lessons/1844

# %% [markdown]
# #이분탐색
# https://school.programmers.co.kr/learn/courses/30/parts/12486
# ### 개념:
# >탐색 범위를 두 부분으로 분할하면서 찾는 방식
#
# ### 유형: 소요되는 자원의 최솟값 찾기
# >입국 심사 / 징검다리
#
# ### 킥: 중간 값인 mid 값을 설정해라
# > mid = (start + end) // 2
#
# 참고 사이트 : https://gyoogle.dev/blog/algorithm/Binary%20Search.html
#
# ### 예제:
# https://school.programmers.co.kr/learn/courses/30/lessons/43238
#
# https://school.programmers.co.kr/learn/courses/30/lessons/43236

# %% [markdown]
# #그래프
# https://school.programmers.co.kr/learn/courses/30/parts/14393
#
# * 그래프는 풀이가 각기 달라 따로 정리하지 않음
